# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

#dataset locations
#dataset_path = 'C:\Users\joseph\Documents\VSCodeProjects\Defects-AI-Analyzer\3DPrintDefectDataset'
dataset_path_macos = '/Users/mrmicfatfat/Documents/VSCodeFiles/Defects-AI-Analyzer/3DPrintDefectDataset'

#Defect Folder path
#defect_folder = os.path.join(dataset_path, 'defected')
defect_folder_macos = os.path.join(dataset_path_macos)
#Non-defect Folder path
#non_defect_folder = os.path.join(data_path, 'no_defected')


#defect_filenames = os.listdir(defect_folder)
defect_filenames_macos = os.listdir(defect_folder_macos)

#image_to_open = defect_filenames[0]
image_to_open_macos = defect_filenames_macos[1]

#full_image_path = os.path.join(defect_folder, image_to_open)
full_image_path_macos = os.path.join(defect_folder_macos, image_to_open_macos)
#print(f"Opening image: {full_image_path}")
print(f"Opening image: {full_image_path_macos}")

defect_folder_macos_images = '/Users/mrmicfatfat/Documents/VSCodeFiles/Defects-AI-Analyzer/3DPrintDefectDataset/defected'
defect_folder_macos_one = defect_folder_macos_images[0]
print(defect_folder_macos_one)
# Out:
# Opening image: /Users/mrmicfatfat/Documents/VSCodeFiles/Defects-AI-Analyzer/3DPrintDefectDataset/defected
# /
